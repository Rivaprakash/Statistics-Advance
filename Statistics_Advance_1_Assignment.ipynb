# %% [markdown]
# 1. What is a random variable in probability theory.
#
# Ans- A random variable is a number that represents the outcome of a random event. It can take different values based on chance.
#
# For example, if we roll a die, the result (1 to 6) is a random variable. There are two types:
#
# * Discrete: Takes specific values (e.g., number of heads in a coin toss).
#
# * Continuous: Takes any value in a range (e.g., temperature of a city).

# %% [markdown]
# 2. What are the types of random variables?
#
# Ans- There are two types of random variables:
#
# * Discrete Random Variable: Takes specific, countable values (e.g., number of students in a class).
#
# * Continuous Random Variable: Takes any value in a range (e.g., height of a person).

# %% [markdown]
# 3. What is the difference between discrete and continuous distributions?
#
# Ans- The difference between discrete and continuous distributions are:
#
# * Discrete Distribution: Deals with countable values (e.g., rolling a die, number of calls received).
#
# * Continuous Distribution: Deals with values in a range (e.g., weight, temperature).

# %% [markdown]
# 4.  What are probability distribution functions (PDF)?
#
# Ans- A Probability Distribution Function (PDF) shows how likely different values of a random variable are.
#
# For discrete variables, it's called Probability Mass Function (PMF) (e.g., chances of rolling a 3 on a die).
#
# For continuous variables, it’s called Probability Density Function (PDF) (e.g., height distribution in a city).

# %% [markdown]
# 5.  How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
#
# Ans- The difference between cumulative distribution functions (CDF) and probability distribution functions (PDF) are:
#
# * Probability distribution functions PDF (or PMF for discrete) gives the probability of a specific value.
#
# * Cumulative distribution functions CDF gives the probability of a value being less than or equal to a given number.

# %% [markdown]
# 6.  What is a discrete uniform distribution.
#
# Ans- A Discrete Uniform Distribution is when all possible values of a discrete random variable have equal probability.
#
# Example: Rolling a fair die (1 to 6). Each number has a 1/6 chance of appearing.

# %% [markdown]
# 7.  What are the key properties of a Bernoulli distribution?
#
# Ans- The key properties of a Bernoulli distribution are:
#
# * Only two outcomes – Success (1) or Failure (0).
#
# * Single trial – One-time experiment (e.g., flipping a coin once).
#
# * Probability (p) – Success happens with probability p, failure with 1 - p.
#
# * Mean = p, Variance = p(1 - p)

# %% [markdown]
# 8.  What is the binomial distribution, and how is it used in probability?
#
# Ans- A Binomial Distribution is used for repeated independent Bernoulli trials (yes/no outcomes).
#
# * Fixed number of trials (n)
#
# * Each trial has success probability (p)
#
# * Counts the number of successes in n trials
#
# Example:
#
# Flipping a fair coin 10 times and counting how many times heads appear follows a binomial distribution.

# %% [markdown]
# 9.  What is the Poisson distribution and where is it applied?
#
# Ans- The Poisson Distribution models the number of times an event happens in a fixed time or space when events occur randomly and independently.
#
# * Used for rare events occurring at an average rate (λ).
#
# * Mean and variance are both λ.
#
# Applications:
#
# * Number of calls at a call center per hour.
#
# * Number of accidents on a road per day.

# %% [markdown]
# 10.  What is a continuous uniform distribution?
#
# Ans- A Continuous Uniform Distribution is when all values in a given range are equally likely.
#
# * Defined by minimum (a) and maximum (b) values.
#
# * Probability is uniform across the range.
#
# * PDF = 1 / (b - a) for a ≤ x ≤ b.
#
# Example:
#
# Choosing a random time between 2 PM and 4 PM.

# %% [markdown]
# 11. What are the characteristics of a normal distribution?
#
# Ans- A Normal Distribution (Gaussian) has these key characteristics:
#
# * Bell-shaped and symmetric around the mean (μ).
#
# * Mean = Median = Mode.
#
# * Spread controlled by standard deviation (σ).
#
# * 68-95-99.7 Rule – Most values fall within 1σ, 2σ, or 3σ of the mean.
#
# * Total area under the curve = 1 (represents probability).

# %% [markdown]
# 12.  What is the standard normal distribution, and why is it important?
#
# Ans- The Standard Normal Distribution is a normal distribution with:
#
# * Mean (μ) = 0
#
# * Standard deviation (σ) = 1
#
# Importance:
#
# * Allows comparison of different normal distributions.
#
# * Uses Z-scores to standardize values.
#
# * Helps in probability calculations and statistical tests.

# %% [markdown]
# 13.  What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#
# Ans- It states that, the sampling distribution of the mean approaches a normal distribution, no matter the population’s shape, if the sample size is large enough (n ≥ 30).
#
# Importance:
#
# * Allows us to use normal probability for many real-world problems.
#
# * Helps in hypothesis testing and confidence intervals.

# %% [markdown]
# 14.  How does the Central Limit Theorem relate to the normal distribution?
#
# Ans- No matter the shape of the original population, the sample mean follows a normal distribution if the sample size is large enough (n ≥ 30).
#
# Key Connection:
#
# * The larger the sample size, the closer the sample mean gets to a normal distribution, even if the population is skewed.
#
# * This is why normal distribution is widely used in statistics.

# %% [markdown]
# 15.  What is the application of Z statistics in hypothesis testing?
#
# Ans- Z-statistics is used in hypothesis testing when:
#
# * Sample size is large (n ≥ 30).
#
# * Population variance (σ²) is known.
#
# Applications:
#
# * Z-test for mean: Checks if a sample mean differs from a population mean.
#
# * Z-test for proportion: Compares sample and population proportions.
#
# * Comparing two means: Tests if two sample means are significantly different.

# %% [markdown]
# 16. How do you calculate a Z-score, and what does it represent?
#
# Ans- Z-score Formula:
# 𝑍 = 𝑋 − 𝜇 / 𝜎
#
# Where:
#
# X = Individual value
#
# μ = Mean of the population
#
# σ = Standard deviation
#
# It Represents:
#
# * How far a value is from the mean in terms of standard deviations.
#
# * Positive Z-score → Value is above the mean.
#
# * Negative Z-score → Value is below the mean.

# %% [markdown]
# 17.  What are point estimates and interval estimates in statistics?
#
# Ans- Point estimates:
#
# * A single value used to estimate a population parameter.
#
# * Example: The sample mean (𝑥̄) estimates the population mean (μ).
#
# Interval Estimate:
#
# * A range of values that likely contains the population parameter, with a confidence level.
#
# * Example: Confidence Interval (CI) for a population mean, like (45, 55) at 95% confidence.

# %% [markdown]
# 18.  What is the significance of confidence intervals in statistical analysis?
#
# Ans- Significance of Confidence Intervals (CIs):
#
# * Estimates Population Parameters – Provides a range instead of a single value.
#
# * Measures Precision – A narrow CI means more precise estimation.
#
# * Shows Uncertainty – Accounts for sample variability.
#
# * Helps in Decision-Making – Used in research, business, and medical studies.

# %% [markdown]
# 19.  What is the relationship between a Z-score and a confidence interval?
#
# Ans- Relationship Between Z-score & Confidence Interval (CI):
#
# * Z-score determines the CI range in a normal distribution.
#
# * Higher Z-scores give wider confidence intervals, meaning more certainty.
#
# Common Z-scores for CIs:
#
# * 90% CI → Z = 1.645
#
# * 95% CI → Z = 1.96
#
# * 99% CI → Z = 2.576

# %% [markdown]
# 20.  How are Z-scores used to compare different distributions?
#
# Ans- Z-Scores Help Compare Different Distributions:
#
# * Standardizes Values – Converts values from different distributions to a common scale.
#
# * Removes Units – Allows direct comparison, regardless of original measurement units.
#
# * Identifies Extremes – Helps find outliers in different datasets.

# %% [markdown]
# 21.  What are the assumptions for applying the Central Limit Theorem?
#
# Ans- Assumptions for the Central Limit Theorem (CLT):
#
# * Random Sampling: Data must be collected randomly.
#
# * Independence: Each sample should be independent of others.
#
# * Sample Size (n ≥ 30): Larger samples lead to a normal distribution, even if the population is not normal.
#
# * Finite Variance: The population should have a finite standard deviation (σ).

# %% [markdown]
# 22.  What is the concept of expected value in a probability distribution?
#
# Ans- The expected value (E[X]) is the average outcome of a probability distribution over many trials.

# %% [markdown]
# 23. How does a probability distribution relate to the expected outcome of a random variable?
#
# Ans- A probability distribution shows the chances of different values occurring for a random variable. The expected outcome (expected value) is the average result over many trials, calculated using the probabilities.

# %%
#1. Write a Python program to generate a random variable and display its value.

import random

random_variable = random.randint(1, 10)

# Display the random variable
print("Generated Random Variable:", random_variable)
# Out:
# Generated Random Variable: 4

# %%
#2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

a, b = 1, 10

# Generate discrete uniform distribution
x = np.arange(a, b + 1)
p = stats.randint.pmf(x, a, b + 1)

# Plot PMF
plt.bar(x, p, color='blue', alpha=0.7, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Probability')
plt.title('Discrete Uniform Distribution PMF')
plt.show()

# %%
#3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

def bernoulli_pdf(p, x):
    """Calculate the probability distribution function (PDF) of a Bernoulli distribution."""
    return stats.bernoulli.pmf(x, p)

p = 0.5  # Probability of success
x = [0, 1]  # Possible values in a Bernoulli distribution
pdf_values = bernoulli_pdf(p, x)

# Plot Bernoulli PDF
plt.bar(x, pdf_values, color='blue', alpha=0.7, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Probability')
plt.title('Bernoulli Distribution PDF')
plt.xticks([0, 1])
plt.show()

# %%
#4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Parameters for binomial distribution
n, p = 10, 0.5
samples = np.random.binomial(n, p, 1000)  # Generate 1000 samples

# Plot histogram using seaborn
sns.histplot(samples, bins=np.arange(n+2)-0.5, kde=False, stat="density", color="orange", edgecolor="black")

plt.xlabel("Number of Successes")
plt.ylabel("Probability")
plt.title("Binomial Distribution (n=10, p=0.5)")
plt.xticks(range(n+1))
plt.grid()
plt.show()

# %%
#5. Create a Poisson distribution and visualize it using Python

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Define the Poisson distribution parameter (mean number of events)
lambda_value = 4

# Generate Poisson probabilities
x_poisson = np.arange(0, 15)
poisson_pmf = stats.poisson.pmf(x_poisson, lambda_value)

# Plot using scatter instead of bar
plt.scatter(x_poisson, poisson_pmf, color='purple', label='Poisson PMF', s=80)
plt.vlines(x_poisson, 0, poisson_pmf, colors='purple', linestyles='dashed')

plt.xlabel('Number of Events')
plt.ylabel('Probability')
plt.title('Poisson Distribution (λ=4)')
plt.legend()
plt.grid()
plt.show()

# %%
#6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution.

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Define parameters for the discrete uniform distribution
a, b = 1, 10  # Range of values
x_values = np.arange(a, b + 1)  # Possible values

# Calculate the CDF using SciPy
cdf_values = stats.randint.cdf(x_values, a, b + 1)

# Plot the CDF using a step plot
plt.step(x_values, cdf_values, where='mid', color='blue', linestyle='-', marker='o', label="CDF")

plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.title('Cumulative Distribution Function (CDF) of Discrete Uniform Distribution')
plt.legend()
plt.grid()
plt.show()

# %%
#7. Generate a continuous uniform distribution using NumPy and visualize it.

import numpy as np
import matplotlib.pyplot as plt

# Generate random samples from a continuous uniform distribution
a, b = 0, 1  # Range of values
samples = np.random.uniform(a, b, 1000)

# Plot histogram
plt.hist(samples, bins=30, density=True, alpha=0.7, color='green', edgecolor='black')

# Add a horizontal line representing the uniform PDF
plt.axhline(y=1/(b-a), color='red', linestyle='--', label='Theoretical PDF')

plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Continuous Uniform Distribution')
plt.legend()
plt.grid()
plt.show()

# %%
#8. Simulate data from a normal distribution and plot its histogram.

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Simulate data from a normal distribution
mu, sigma = 0, 1  # Mean and standard deviation
normal_samples = np.random.normal(mu, sigma, 1000)  # Generate 1000 samples

# Plot histogram using seaborn
sns.histplot(normal_samples, bins=30, kde=True, color="blue", edgecolor="black")
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Normal Distribution Histogram with KDE')
plt.show()

# %%
#9. Write a Python function to calculate Z-scores from a dataset and plot them.

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

# Function to calculate and plot Z-scores
def calculate_and_plot_z_scores_alt(data):
    z_scores = zscore(data)  # Using scipy's built-in function

    # Plot Z-scores
    plt.figure(figsize=(8, 5))
    sns.histplot(z_scores, bins=30, kde=True, color='orange', edgecolor='black')
    plt.xlabel('Z-score')
    plt.ylabel('Frequency')
    plt.title('Z-score Distribution (Alternative Method)')
    plt.grid()
    plt.show()

    return z_scores

# Generate random dataset and plot Z-scores
random_data = np.random.normal(50, 10, 1000)
z_scores_alt = calculate_and_plot_z_scores_alt(random_data)

# %%
#10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Central Limit Theorem Simulation
def clt_simulation(sample_size=30, num_samples=1000):
    original_dist = np.random.exponential(scale=2, size=10000)
    sample_means = [np.mean(np.random.choice(original_dist, sample_size)) for _ in range(num_samples)]

    sns.histplot(sample_means, bins=30, kde=True, color='purple')
    plt.title('CLT Simulation (Exponential Distribution)')
    plt.show()

clt_simulation()

# %%
#11. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Verify Central Limit Theorem with Normal Distribution
def verify_clt(sample_size=30, num_samples=1000):
    population = np.random.normal(loc=5, scale=2, size=10000)
    sample_means = [np.mean(np.random.choice(population, sample_size)) for _ in range(num_samples)]

    sns.histplot(sample_means, bins=30, kde=True, color='blue')
    plt.title('CLT Verification (Normal Distribution)')
    plt.show()

verify_clt()

# %%
#12. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# Standard Normal Distribution
def plot_standard_normal():
    x = np.linspace(-4, 4, 1000)
    y = stats.norm.pdf(x, 0, 1)

    plt.plot(x, y, color='blue', label='Standard Normal Distribution')
    plt.xlabel('Z-score')
    plt.ylabel('Density')
    plt.title('Standard Normal Distribution (Mean=0, Std=1)')
    plt.legend()
    plt.show()

plot_standard_normal()

# %%
#13. Generate random variables and calculate their corresponding probabilities using the binomial distribution

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# Generate random variables and calculate probabilities using Binomial Distribution
def binomial_distribution(n=10, p=0.5, size=1000):
    samples = np.random.binomial(n, p, size)
    unique, counts = np.unique(samples, return_counts=True)
    probabilities = counts / size

    plt.bar(unique, probabilities, color='green', edgecolor='black')
    plt.xlabel('Number of Successes')
    plt.ylabel('Probability')
    plt.title('Binomial Distribution')
    plt.show()

binomial_distribution()

# %%
#14. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Generate data and calculate Z-score
data = np.random.normal(50, 10, 1000)
point, z_score = 55, (55 - np.mean(data)) / np.std(data)

# Plot Standard Normal Distribution
x = np.linspace(-4, 4, 1000)
plt.plot(x, stats.norm.pdf(x), 'b', label='Standard Normal')
plt.axvline(z_score, color='r', linestyle='--', label=f'Z-score: {z_score:.2f}')
plt.legend(), plt.show()

print(f"Z-score for {point}: {z_score:.2f}")
# Out:
# Z-score for 55: 0.52

# %%
#15. Implement hypothesis testing using Z-statistics for a sample dataset

import numpy as np
import scipy.stats as stats

# Z-test function
def z_test(sample, pop_mean, pop_std):
    z = (np.mean(sample) - pop_mean) / (pop_std / np.sqrt(len(sample)))
    return z, 2 * (1 - stats.norm.cdf(abs(z)))

# Sample data & Z-test
np.random.seed(42)
sample = np.random.normal(50, 10, 30)
z, p = z_test(sample, 50, 10)

print(f"Z-score: {z:.2f}, P-value: {p:.4f}")
print("Reject null" if p < 0.05 else "Fail to reject null")
# Out:
# Z-score: -1.03, P-value: 0.3028
# Fail to reject null

# %%
#16. Create a confidence interval for a dataset using Python and interpret the result.

import numpy as np
import scipy.stats as stats

# Confidence Interval Function
def confidence_interval(sample, confidence=0.95):
    mean = np.mean(sample)
    sem = stats.sem(sample)
    margin = stats.t.ppf((1 + confidence) / 2, df=len(sample)-1) * sem
    return mean - margin, mean + margin

# Generate sample data
np.random.seed(42)
sample = np.random.normal(50, 10, 30)

# Compute Confidence Interval
ci_lower, ci_upper = confidence_interval(sample)

print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
print("Interpretation: We are 95% confident that the true population mean lies within this interval.")
# Out:
# 95% Confidence Interval: (44.76, 51.48)
# Interpretation: We are 95% confident that the true population mean lies within this interval.

# %%
#17. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

import numpy as np
import scipy.stats as stats

# Generate normal distribution data
np.random.seed(42)
data = np.random.normal(50, 10, 30)

# Compute confidence interval
def confidence_interval(data, confidence=0.95):
    mean, sem = np.mean(data), stats.sem(data)
    margin = stats.t.ppf((1 + confidence) / 2, df=len(data)-1) * sem
    return mean - margin, mean + margin

ci_lower, ci_upper = confidence_interval(data)

print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
print("Interpretation: The true mean likely falls within this range with 95% confidence.")
# Out:
# 95% Confidence Interval: (44.76, 51.48)
# Interpretation: The true mean likely falls within this range with 95% confidence.

# %%
#18. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Generate normal distribution data
x = np.linspace(-4, 4, 1000)
pdf = stats.norm.pdf(x, 0, 1)

# Plot PDF
plt.plot(x, pdf, color='blue', label='Normal Distribution PDF')
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Probability Density Function of Normal Distribution')
plt.legend()
plt.show()

# %%
#19. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Define Poisson distribution parameters
lambda_val = 5
x = np.arange(0, 15)
cdf = stats.poisson.cdf(x, lambda_val)

# Plot CDF
plt.step(x, cdf, where='mid', color='blue', label='Poisson CDF')
plt.xlabel('Number of Events')
plt.ylabel('Cumulative Probability')
plt.title('Cumulative Distribution Function of Poisson Distribution')
plt.legend()
plt.show()

# Interpretation
print("CDF values:", cdf)
print("Interpretation: The CDF shows the probability of observing up to a certain number of events in a Poisson process.")
# Out:
# CDF values: [0.00673795 0.04042768 0.12465202 0.26502592 0.44049329 0.61596065
#  0.76218346 0.86662833 0.93190637 0.96817194 0.98630473 0.99454691
#  0.99798115 0.99930201 0.99977375]
# Interpretation: The CDF shows the probability of observing up to a certain number of events in a Poisson process.

# %%
#20. Simulate a random variable using a continuous uniform distribution and calculate its expected value.

import numpy as np
import scipy.stats as stats

# Simulate continuous uniform distribution
a, b = 0, 10  # Lower and upper bounds
samples = np.random.uniform(a, b, 1000)

# Calculate expected value
expected_value = (a + b) / 2

print(f"Simulated Expected Value: {np.mean(samples):.2f}")
print(f"Theoretical Expected Value: {expected_value:.2f}")
# Out:
# Simulated Expected Value: 4.95
# Theoretical Expected Value: 5.00

# %%
#21. Write a Python program to compare the standard deviations of two datasets and visualize the difference.

import numpy as np
import matplotlib.pyplot as plt

# Generate two datasets
np.random.seed(42)
data1 = np.random.normal(50, 10, 1000)
data2 = np.random.normal(50, 20, 1000)

# Compute standard deviations
std1, std2 = np.std(data1, ddof=1), np.std(data2, ddof=1)

# Visualization using boxplot
plt.boxplot([data1, data2], labels=[f'Dataset 1 (Std: {std1:.2f})', f'Dataset 2 (Std: {std2:.2f})'])
plt.ylabel('Value')
plt.title('Comparison of Standard Deviations')
plt.show()

# Print standard deviations
print(f"Standard Deviation of Dataset 1: {std1:.2f}")
print(f"Standard Deviation of Dataset 2: {std2:.2f}")
# Out:
# <ipython-input-28-ab0d8d781ea7>:15: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([data1, data2], labels=[f'Dataset 1 (Std: {std1:.2f})', f'Dataset 2 (Std: {std2:.2f})'])
# Standard Deviation of Dataset 1: 9.79
# Standard Deviation of Dataset 2: 19.95

# %%
#22. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.

import numpy as np
import scipy.stats as stats

# Generate dataset from normal distribution
np.random.seed(42)
data = np.random.normal(50, 15, 1000)

# Calculate range and IQR
range_val = np.max(data) - np.min(data)
q1, q3 = np.percentile(data, [25, 75])
iqr = q3 - q1

# Print results
print(f"Range: {range_val:.2f}")
print(f"Interquartile Range (IQR): {iqr:.2f}")
# Out:
# Range: 106.41
# Interquartile Range (IQR): 19.43

# %%
#23. Implement Z-score normalization on a dataset and visualize its transformation.

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Generate dataset
np.random.seed(42)
data = np.random.normal(50, 15, 1000)

# Apply Z-score normalization
z_scores = (data - np.mean(data)) / np.std(data)

# Visualization
plt.figure(figsize=(10, 5))
plt.hist(data, bins=30, alpha=0.5, label='Original Data', color='blue')
plt.hist(z_scores, bins=30, alpha=0.5, label='Z-score Normalized Data', color='red')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Comparison of Original and Z-score Normalized Data')
plt.legend()
plt.show()

# Print summary statistics
print(f"Original Mean: {np.mean(data):.2f}, Standard Deviation: {np.std(data):.2f}")
print(f"Normalized Mean: {np.mean(z_scores):.2f}, Standard Deviation: {np.std(z_scores):.2f}")
# Out:
# Original Mean: 50.29, Standard Deviation: 14.68
# Normalized Mean: 0.00, Standard Deviation: 1.00

# %%
#24. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.

import numpy as np
import scipy.stats as stats

# Generate dataset from normal distribution
np.random.seed(42)
data = np.random.normal(50, 15, 1000)

# Calculate skewness and kurtosis
skewness = stats.skew(data)
kurtosis = stats.kurtosis(data)

# Print results
print(f"Skewness: {skewness:.2f}")
print(f"Kurtosis: {kurtosis:.2f}")
# Out:
# Skewness: 0.12
# Kurtosis: 0.07
